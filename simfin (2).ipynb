# %%
import simfin as sf
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from collections import Counter

# %%
# Set API Key 
sf.set_api_key('ZLj424KDiohtSc0u9bVaF7mIeIemoAir')

# %%
# Make Directory for Data 
sf.set_data_dir('~/simfin_data/')

# %%
ratios_df = sf.load_derived(variant='quarterly-asreported', market='us')
print(ratios_df.head())
# Out:
# Dataset "us-derived-quarterly-asreported" on disk (1 days old).
# - Loading from disk ... Done!
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2010-07-31      45846      USD         2010            Q3   2010-10-06
#        2010-10-31      45846      USD         2010            Q4   2010-12-20
#        2011-01-31      45846      USD         2011            Q1   2011-03-09
#        2011-04-30      45846      USD         2011            Q2   2011-06-07
#        2011-07-31      45846      USD         2011            Q3   2011-09-07
#
#                    Restated Date       EBITDA  Total Debt  Free Cash Flow  \
# Ticker Report Date
# A      2010-07-31     2011-09-07  175000000.0  3678000000     174000000.0
#        2010-10-31     2012-12-20  270000000.0  3691000000     258000000.0
#        2011-01-31     2012-03-05  274000000.0  2139000000      65000000.0
#        2011-04-30     2012-06-04  330000000.0  2144000000     393000000.0
#        2011-07-31     2012-09-05  344000000.0  2168000000      74000000.0
#
#                     Gross Profit Margin  ...  Sales Per Share  \
# Ticker Report Date                       ...
# A      2010-07-31               0.52384  ...          3.98847
#        2010-10-31               0.52919  ...          4.58140
#        2011-01-31               0.53720  ...          4.37752
#        2011-04-30               0.53667  ...          4.83285
#        2011-07-31               0.52750  ...          4.85920
#
#                     Equity Per Share  Free Cash Flow Per Share  \
# Ticker Report Date
# A      2010-07-31            8.07493                   0.50144
#        2010-10-31            9.38372                   0.75000
#        2011-01-31            9.60231                   0.18732
#        2011-04-30           11.39193                   1.13256
#        2011-07-31           12.04598                   0.21264
#
#                     Dividends Per Share  Piotroski F-Score  \
# Ticker Report Date
# A      2010-07-31                   NaN                NaN
#        2010-10-31                   0.0                6.0
#        2011-01-31                   NaN                NaN
#        2011-04-30                   0.0                NaN
#        2011-07-31                   0.0                6.0
#
#                     Return On Invested Capital  \
# Ticker Report Date
# A      2010-07-31                      0.02668
#        2010-10-31                      0.03599
#        2011-01-31                      0.02907
#        2011-04-30                      0.02834
#        2011-07-31                      0.04553
#
#                     Cash Return On Invested Capital  Dividend Payout Ratio  \
# Ticker Report Date
# A      2010-07-31                           0.02264                    NaN
#        2010-10-31                           0.03180                    0.0
#        2011-01-31                           0.00979                    NaN
#        2011-04-30                           0.05569                    0.0
#        2011-07-31                           0.01021                    0.0
#
#                     Net Debt / EBITDA  Net Debt / EBIT
# Ticker Report Date
# A      2010-07-31             7.77714         11.83478
#        2010-10-31             3.85926          5.13300
#        2011-01-31            -1.82117         -2.36493
#        2011-04-30            -2.51818         -3.12406
#        2011-07-31            -2.71221         -3.32028
#
# [5 rows x 30 columns]

# %%
pd.DataFrame(ratios_df)
# Out:
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2010-07-31      45846      USD         2010            Q3   2010-10-06
#        2010-10-31      45846      USD         2010            Q4   2010-12-20
#        2011-01-31      45846      USD         2011            Q1   2011-03-09
#        2011-04-30      45846      USD         2011            Q2   2011-06-07
#        2011-07-31      45846      USD         2011            Q3   2011-09-07
# ...                      ...      ...          ...           ...          ...
# ZYXI   2020-09-30     171401      USD         2020            Q3   2020-10-27
#        2020-12-31     171401      USD         2020            Q4   2021-02-25
#        2021-03-31     171401      USD         2021            Q1   2021-04-29
#        2021-06-30     171401      USD         2021            Q2   2021-07-29
#        2021-09-30     171401      USD         2021            Q3   2021-11-02
#
#                    Restated Date       EBITDA  Total Debt  Free Cash Flow  \
# Ticker Report Date
# A      2010-07-31     2011-09-07  175000000.0  3678000000     174000000.0
#        2010-10-31     2012-12-20  270000000.0  3691000000     258000000.0
#        2011-01-31     2012-03-05  274000000.0  2139000000      65000000.0
#        2011-04-30     2012-06-04  330000000.0  2144000000     393000000.0
#        2011-07-31     2012-09-05  344000000.0  2168000000      74000000.0
# ...                          ...          ...         ...             ...
# ZYXI   2020-09-30     2020-10-27    1914000.0           0             NaN
#        2020-12-31     2021-02-25    2827000.0           0      -3070000.0
#        2021-03-31     2021-04-29    -594000.0           0      -6150000.0
#        2021-06-30     2021-07-29    4422000.0           0       1714000.0
#        2021-09-30     2021-11-02    8641000.0           0       6443000.0
#
#                     Gross Profit Margin  ...  Sales Per Share  \
# Ticker Report Date                       ...
# A      2010-07-31               0.52384  ...          3.98847
#        2010-10-31               0.52919  ...          4.58140
#        2011-01-31               0.53720  ...          4.37752
#        2011-04-30               0.53667  ...          4.83285
#        2011-07-31               0.52750  ...          4.85920
# ...                                 ...  ...              ...
# ZYXI   2020-09-30               0.78548  ...          0.52791
#        2020-12-31               0.77899  ...          0.66900
#        2021-03-31               0.75604  ...          0.62961
#        2021-06-30               0.76575  ...          0.81016
#        2021-09-30               0.80346  ...          0.90956
#
#                     Equity Per Share  Free Cash Flow Per Share  \
# Ticker Report Date
# A      2010-07-31            8.07493                   0.50144
#        2010-10-31            9.38372                   0.75000
#        2011-01-31            9.60231                   0.18732
#        2011-04-30           11.39193                   1.13256
#        2011-07-31           12.04598                   0.21264
# ...                              ...                       ...
# ZYXI   2020-09-30            1.43170                       NaN
#        2020-12-31            1.48550                  -0.08021
#        2021-03-31            1.46534                  -0.16049
#        2021-06-30            1.49644                   0.04476
#        2021-09-30            1.65730                   0.16847
#
#                     Dividends Per Share  Piotroski F-Score  \
# Ticker Report Date
# A      2010-07-31                   NaN                NaN
#        2010-10-31                   0.0                6.0
#        2011-01-31                   NaN                NaN
#        2011-04-30                   0.0                NaN
#        2011-07-31                   0.0                6.0
# ...                                 ...                ...
# ZYXI   2020-09-30                   0.0                2.0
#        2020-12-31                   NaN                2.0
#        2021-03-31                   NaN                1.0
#        2021-06-30                   NaN                3.0
#        2021-09-30                   NaN                5.0
#
#                     Return On Invested Capital  \
# Ticker Report Date
# A      2010-07-31                      0.02668
#        2010-10-31                      0.03599
#        2011-01-31                      0.02907
#        2011-04-30                      0.02834
#        2011-07-31                      0.04553
# ...                                        ...
# ZYXI   2020-09-30                      0.02311
#        2020-12-31                      0.02880
#        2021-03-31                     -0.01159
#        2021-06-30                      0.03754
#        2021-09-30                      0.07593
#
#                     Cash Return On Invested Capital  Dividend Payout Ratio  \
# Ticker Report Date
# A      2010-07-31                           0.02264                    NaN
#        2010-10-31                           0.03180                    0.0
#        2011-01-31                           0.00979                    NaN
#        2011-04-30                           0.05569                    0.0
#        2011-07-31                           0.01021                    0.0
# ...                                             ...                    ...
# ZYXI   2020-09-30                               NaN                    0.0
#        2020-12-31                          -0.04947                    NaN
#        2021-03-31                          -0.10095                    NaN
#        2021-06-30                           0.02291                    NaN
#        2021-09-30                           0.08011                    NaN
#
#                     Net Debt / EBITDA  Net Debt / EBIT
# Ticker Report Date
# A      2010-07-31             7.77714         11.83478
#        2010-10-31             3.85926          5.13300
#        2011-01-31            -1.82117         -2.36493
#        2011-04-30            -2.51818         -3.12406
#        2011-07-31            -2.71221         -3.32028
# ...                               ...              ...
# ZYXI   2020-09-30           -21.54075        -29.26118
#        2020-12-31           -13.85674        -17.05398
#        2021-03-31            56.29461         30.93340
#        2021-06-30            -7.31117         -8.47444
#        2021-09-30            -4.09304         -4.39572
#
# [84083 rows x 30 columns]

# %%
ratios_df.reset_index(inplace=True)

companies_dirty = ratios_df['Ticker'].to_list()

companies_clean = []
[companies_clean.append(x) for x in companies_dirty if x not in companies_clean]

char_list = ['_','1','ACPW', 'ADFK', 'ALTMS', 'ARTEC', 'AUDH', 'BCLR', 'BCSI', 'BLUD', 'C649', 'CCFI', 'CICC', 'CMBG', 'CYNX', 'DDMG', 'DGTC', 'DMDW', 'ELLI', 'EXDX', 'HOMR', 'INFOR', 'JCG', 'JDAS', 'LOXO', 'LTCH', 'MFE', 'NCSO', 'NDMT', 
             'NKT.CO', 'NOIZ', 'QVC', 'SCRH', 'SNGC', 'TM-28', 'TMB', 'VNTV', 'WLT', 'XING']
companies_clean = [ele for ele in companies_clean if all(ch not in ele for ch in char_list)]


ratios_df.rename(columns={'Publish Date':'Date'},inplace=True)
ratios_df.set_index(['Ticker', 'Date'], inplace=True)
#ratios_df.drop(columns=['Free Cash Flow', 'EBITDA', 'Total Debt', 'SimFinId','Currency', 'Report Date','Restated Date'],inplace=True)
ratios_df.head()
# Out:
#                    Fiscal Year Fiscal Period  Gross Profit Margin  \
# Ticker Date
# A      2010-10-06         2010            Q3              0.52384
#        2010-12-20         2010            Q4              0.52919
#        2011-03-09         2011            Q1              0.53720
#        2011-06-07         2011            Q2              0.53667
#        2011-09-07         2011            Q3              0.52750
#
#                    Operating Margin  Net Profit Margin  Return on Equity  \
# Ticker Date
# A      2010-10-06           0.08309            0.14812           0.07295
#        2010-12-20           0.12881            0.18528           0.09023
#        2011-03-09           0.13891            0.12706           0.05780
#        2011-06-07           0.15862            0.11926           0.05049
#        2011-09-07           0.16617            0.19515           0.07857
#
#                    Return on Assets  Free Cash Flow to Net Income  \
# Ticker Date
# A      2010-10-06           0.02253                       0.84878
#        2010-12-20           0.03012                       0.88356
#        2011-03-09           0.02399                       0.33679
#        2011-06-07           0.02312                       1.96500
#        2011-09-07           0.03770                       0.22424
#
#                    Current Ratio  Liabilities to Equity Ratio  ...  \
# Ticker Date                                                    ...
# A      2010-10-06        1.96606                      2.23843  ...
#        2010-12-20        2.00097                      1.99629  ...
#        2011-03-09        3.27027                      1.40910  ...
#        2011-06-07        3.20101                      1.18354  ...
#        2011-09-07        3.47043                      1.08405  ...
#
#                    Sales Per Share  Equity Per Share  \
# Ticker Date
# A      2010-10-06          3.98847           8.07493
#        2010-12-20          4.58140           9.38372
#        2011-03-09          4.37752           9.60231
#        2011-06-07          4.83285          11.39193
#        2011-09-07          4.85920          12.04598
#
#                    Free Cash Flow Per Share  Dividends Per Share  \
# Ticker Date
# A      2010-10-06                   0.50144                  NaN
#        2010-12-20                   0.75000                  0.0
#        2011-03-09                   0.18732                  NaN
#        2011-06-07                   1.13256                  0.0
#        2011-09-07                   0.21264                  0.0
#
#                    Piotroski F-Score  Return On Invested Capital  \
# Ticker Date
# A      2010-10-06                NaN                     0.02668
#        2010-12-20                6.0                     0.03599
#        2011-03-09                NaN                     0.02907
#        2011-06-07                NaN                     0.02834
#        2011-09-07                6.0                     0.04553
#
#                    Cash Return On Invested Capital  Dividend Payout Ratio  \
# Ticker Date
# A      2010-10-06                          0.02264                    NaN
#        2010-12-20                          0.03180                    0.0
#        2011-03-09                          0.00979                    NaN
#        2011-06-07                          0.05569                    0.0
#        2011-09-07                          0.01021                    0.0
#
#                    Net Debt / EBITDA  Net Debt / EBIT
# Ticker Date
# A      2010-10-06            7.77714         11.83478
#        2010-12-20            3.85926          5.13300
#        2011-03-09           -1.82117         -2.36493
#        2011-06-07           -2.51818         -3.12406
#        2011-09-07           -2.71221         -3.32028
#
# [5 rows x 23 columns]

# %%
prices_df = sf.load_shareprices(variant='daily', market='us')
# Out:
# Dataset "us-shareprices-daily" on disk (1 days old).
# - Loading from disk ... Done!

# %%
prices_df.columns
prices_df.drop(columns=['Open', 'Low', 'High', 'Close', 'Dividend',
       'Volume', 'Shares Outstanding'], inplace=True)

# %%
#prices_df.set_index(['Ticker', 'Date'], inplace=True)
#prices_df.set_index('Date',inplace=True)
#prices_df.reset_index(inplace=True)

prices_df['pct_change']=prices_df['Adj. Close'].pct_change().shift(-1)

# %%
prices_df.head()
# Out:
#                    SimFinId  Adj. Close  pct_change
# Ticker Date
# A      2007-01-03     45846       22.60    0.003097
#        2007-01-04     45846       22.67   -0.009263
#        2007-01-05     45846       22.46   -0.003562
#        2007-01-08     45846       22.38    0.001340
#        2007-01-09     45846       22.41   -0.008925

# %%
ratios_df.head()
# Out:
#                    Fiscal Year Fiscal Period  Gross Profit Margin  \
# Ticker Date
# A      2010-10-06         2010            Q3              0.52384
#        2010-12-20         2010            Q4              0.52919
#        2011-03-09         2011            Q1              0.53720
#        2011-06-07         2011            Q2              0.53667
#        2011-09-07         2011            Q3              0.52750
#
#                    Operating Margin  Net Profit Margin  Return on Equity  \
# Ticker Date
# A      2010-10-06           0.08309            0.14812           0.07295
#        2010-12-20           0.12881            0.18528           0.09023
#        2011-03-09           0.13891            0.12706           0.05780
#        2011-06-07           0.15862            0.11926           0.05049
#        2011-09-07           0.16617            0.19515           0.07857
#
#                    Return on Assets  Free Cash Flow to Net Income  \
# Ticker Date
# A      2010-10-06           0.02253                       0.84878
#        2010-12-20           0.03012                       0.88356
#        2011-03-09           0.02399                       0.33679
#        2011-06-07           0.02312                       1.96500
#        2011-09-07           0.03770                       0.22424
#
#                    Current Ratio  Liabilities to Equity Ratio  ...  \
# Ticker Date                                                    ...
# A      2010-10-06        1.96606                      2.23843  ...
#        2010-12-20        2.00097                      1.99629  ...
#        2011-03-09        3.27027                      1.40910  ...
#        2011-06-07        3.20101                      1.18354  ...
#        2011-09-07        3.47043                      1.08405  ...
#
#                    Sales Per Share  Equity Per Share  \
# Ticker Date
# A      2010-10-06          3.98847           8.07493
#        2010-12-20          4.58140           9.38372
#        2011-03-09          4.37752           9.60231
#        2011-06-07          4.83285          11.39193
#        2011-09-07          4.85920          12.04598
#
#                    Free Cash Flow Per Share  Dividends Per Share  \
# Ticker Date
# A      2010-10-06                   0.50144                  NaN
#        2010-12-20                   0.75000                  0.0
#        2011-03-09                   0.18732                  NaN
#        2011-06-07                   1.13256                  0.0
#        2011-09-07                   0.21264                  0.0
#
#                    Piotroski F-Score  Return On Invested Capital  \
# Ticker Date
# A      2010-10-06                NaN                     0.02668
#        2010-12-20                6.0                     0.03599
#        2011-03-09                NaN                     0.02907
#        2011-06-07                NaN                     0.02834
#        2011-09-07                6.0                     0.04553
#
#                    Cash Return On Invested Capital  Dividend Payout Ratio  \
# Ticker Date
# A      2010-10-06                          0.02264                    NaN
#        2010-12-20                          0.03180                    0.0
#        2011-03-09                          0.00979                    NaN
#        2011-06-07                          0.05569                    0.0
#        2011-09-07                          0.01021                    0.0
#
#                    Net Debt / EBITDA  Net Debt / EBIT
# Ticker Date
# A      2010-10-06            7.77714         11.83478
#        2010-12-20            3.85926          5.13300
#        2011-03-09           -1.82117         -2.36493
#        2011-06-07           -2.51818         -3.12406
#        2011-09-07           -2.71221         -3.32028
#
# [5 rows x 23 columns]

# %%
def combiner(ticker):
    ticker_ratio = ratios_df.loc[ticker,:]
    ticker_prices = prices_df.loc[ticker,:]
    tickers = pd.merge(ticker_ratio, ticker_prices,left_index=True, right_index=True,how='inner')
   
    return tickers

# %%
companies_clean
# Out:
# ['A',
#  'AA',
#  'AAL',
#  'AAMC',
#  'AAN',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAWW',
#  'ABAX',
#  'ABBV',
#  'ABC',
#  'ABCD',
#  'ABCL',
#  'ABEO',
#  'ABG',
#  'ABIO',
#  'ABM',
#  'ABMC',
#  'ABMD',
#  'ABNB',
#  'ABSI',
#  'ABT',
#  'ABTL',
#  'ABUS',
#  'AC',
#  'ACA',
#  'ACAD',
#  'ACAN',
#  'ACAT',
#  'ACCO',
#  'ACER',
#  'ACET',
#  'ACHC',
#  'ACI',
#  'ACIA',
#  'ACIW',
#  'ACLS',
#  'ACM',
#  'ACN',
#  'ACPW',
#  'ACRX',
#  'ACT',
#  'ACU',
#  'ACW',
#  'ACY',
#  'ADBE',
#  'ADES',
#  'ADFK',
#  'ADI',
#  'ADIL',
#  'ADM',
#  'ADMA',
#  'ADNT',
#  'ADOM',
#  'ADP',
#  'ADPT',
#  'ADS',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADXS',
#  'AE',
#  'AEE',
#  'AEHR',
#  'AEIS',
#  'AEO',
#  'AEP',
#  'AEPI',
#  'AES',
#  'AFI',
#  'AFRM',
#  'AGCO',
#  'AGI',
#  'AGIO',
#  'AGLE',
#  'AGN',
#  'AGNC',
#  'AGR',
#  'AGS',
#  'AGX',
#  'AGYS',
#  'AHPI',
#  'AIMC',
#  'AIR',
#  'AIRI',
#  'AIT',
#  'AJG',
#  'AJRD',
#  'AKAM',
#  'AKR',
#  'AKRX',
#  'AKS',
#  'AKYA',
#  'AL',
#  'ALB',
#  'ALCO',
#  'ALE',
#  'ALG',
#  'ALGN',
#  'ALGT',
#  'ALJ',
#  'ALJJ',
#  'ALK',
#  'ALKS',
#  'ALLE',
#  'ALNY',
#  'ALOT',
#  'ALPN',
#  'ALR',
#  'ALRM',
#  'ALRN',
#  'ALSK',
#  'ALSN',
#  'ALT',
#  'ALTMS',
#  'ALTR',
#  'ALV',
#  'ALX',
#  'ALXN',
#  'AMAT',
#  'AMBA',
#  'AMC',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMKR',
#  'AMN',
#  'AMOT',
#  'AMP',
#  'AMRK',
#  'AMRS',
#  'AMSC',
#  'AMSWA',
#  'AMT',
#  'AMTD',
#  'AMWD',
#  'AMZN',
#  'AN',
#  'ANDV',
#  'ANET',
#  'ANF',
#  'ANGI',
#  'ANIK',
#  'ANSS',
#  'ANY',
#  'AON',
#  'AOS',
#  'AOSL',
#  'AP',
#  'APA',
#  'APC',
#  'APD',
#  'APEI',
#  'APH',
#  'APIC',
#  'APO',
#  'APOG',
#  'APPF',
#  'APPS',
#  'APRE',
#  'APRN',
#  'APTI',
#  'APTV',
#  'APU',
#  'APVO',
#  'APY',
#  'ARA',
#  'ARAY',
#  'ARCB',
#  'ARCH',
#  'ARCW',
#  'ARE',
#  'AREX',
#  'ARG',
#  'ARLO',
#  'ARLP',
#  'ARMK',
#  'ARNA',
#  'ARNC',
#  'ARO',
#  'AROC',
#  'ARQL',
#  'ARRS',
#  'ARRY',
#  'ARTEC',
#  'ARTX',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'ASAN',
#  'ASCMA',
#  'ASGN',
#  'ASH',
#  'ASNA',
#  'ASO',
#  'ASPN',
#  'ASPU',
#  'ASTC',
#  'ASYS',
#  'ATI',
#  'ATKR',
#  'ATNX',
#  'ATO',
#  'ATOM',
#  'ATR',
#  'ATRO',
#  'ATUS',
#  'ATVI',
#  'ATW',
#  'AUDH',
#  'AUGX',
#  'AVA',
#  'AVAV',
#  'AVB',
#  'AVEO',
#  'AVGO',
#  'AVGR',
#  'AVLR',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVP',
#  'AVT',
#  'AVTR',
#  'AVXL',
#  'AVY',
#  'AVYA',
#  'AWI',
#  'AWK',
#  'AWRE',
#  'AWX',
#  'AXGN',
#  'AXL',
#  'AXON',
#  'AXTA',
#  'AXTI',
#  'AY',
#  'AYI',
#  'AYX',
#  'AZO',
#  'AZPN',
#  'AZZ',
#  'BA',
#  'BAH',
#  'BAX',
#  'BB',
#  'BBBY',
#  'BBGI',
#  'BBRG',
#  'BBSI',
#  'BBWI',
#  'BBY',
#  'BC',
#  'BCEI',
#  'BCLR',
#  'BCO',
#  'BCOR',
#  'BCPC',
#  'BCR',
#  'BCSI',
#  'BDC',
#  'BDSX',
#  'BDX',
#  'BE',
#  'BEAM',
#  'BEN',
#  'BERY',
#  'BF-A',
#  'BFAM',
#  'BFS',
#  'BG',
#  'BGCP',
#  'BGFV',
#  'BGG',
#  'BGNE',
#  'BGS',
#  'BGSF',
#  'BH',
#  'BHC',
#  'BHE',
#  'BHI',
#  'BHR',
#  'BID',
#  'BIG',
#  'BIIB',
#  'BIO',
#  'BJ',
#  'BJRI',
#  'BKD',
#  'BKE',
#  'BKH',
#  'BKI',
#  'BKNG',
#  'BKR',
#  'BKS',
#  'BKTI',
#  'BL',
#  'BLCM',
#  'BLD',
#  'BLDR',
#  'BLFS',
#  'BLI',
#  'BLK',
#  'BLKB',
#  'BLL',
#  'BLOX',
#  'BLUD',
#  'BLUE',
#  'BMBL',
#  'BMI',
#  'BMRA',
#  'BMRN',
#  'BMS',
#  'BMY',
#  'BNED',
#  'BNFT',
#  'BNGO',
#  'BONT',
#  'BOOM',
#  'BOOT',
#  'BOX',
#  'BOXL',
#  'BPL',
#  'BPMC',
#  'BPMP',
#  'BR',
#  'BRBR',
#  'BRC',
#  'BRCD',
#  'BRCM',
#  'BREW',
#  'BRID',
#  'BRK-A',
#  'BRKR',
#  'BRKS',
#  'BRMK',
#  'BRO',
#  'BRRE',
#  'BRS',
#  'BRSS',
#  'BRX',
#  'BSET',
#  'BSPM',
#  'BSQR',
#  'BSTC',
#  'BSTG',
#  'BSX',
#  'BSY',
#  'BTAI',
#  'BTU',
#  'BURL',
#  'BV',
#  'BVS',
#  'BVSN',
#  'BWA',
#  'BWLA',
#  'BWXT',
#  'BX',
#  'BXC',
#  'BXP',
#  'BYD',
#  'BYND',
#  'BZH',
#  'C649',
#  'CA',
#  'CABO',
#  'CACC',
#  'CACI',
#  'CAG',
#  'CAGU',
#  'CAH',
#  'CAKE',
#  'CAL',
#  'CALA',
#  'CALD',
#  'CALL',
#  'CALM',
#  'CALX',
#  'CAMP',
#  'CAPL',
#  'CAR',
#  'CARG',
#  'CARR',
#  'CARS',
#  'CASA',
#  'CASI',
#  'CASY',
#  'CAT',
#  'CATO',
#  'CAVM',
#  'CBB',
#  'CBI',
#  'CBKCQ',
#  'CBLK',
#  'CBM',
#  'CBOE',
#  'CBRE',
#  'CBRL',
#  'CBT',
#  'CC',
#  'CCE',
#  'CCF',
#  'CCFI',
#  'CCH',
#  'CCI',
#  'CCK',
#  'CCL',
#  'CCMP',
#  'CCO',
#  'CCOI',
#  'CCS',
#  'CCXI',
#  'CDAY',
#  'CDE',
#  'CDI',
#  'CDK',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDR',
#  'CDW',
#  'CDXS',
#  'CDZI',
#  'CE',
#  'CELC',
#  'CELG',
#  'CELH',
#  'CENT',
#  'CERN',
#  'CERS',
#  'CETX',
#  'CF',
#  'CFMS',
#  'CFX',
#  'CGA',
#  'CGNX',
#  'CGRN',
#  'CHART',
#  'CHD',
#  'CHDN',
#  'CHE',
#  'CHEF',
#  'CHGG',
#  'CHH',
#  'CHJI',
#  'CHKE',
#  'CHNG',
#  'CHRS',
#  'CHRW',
#  'CHSP',
#  'CHTR',
#  'CHWY',
#  'CICC',
#  'CIDM',
#  'CIE',
#  'CIEN',
#  'CIK',
#  'CIVI',
#  'CKP',
#  'CL',
#  'CLAR',
#  'CLBS',
#  'CLC',
#  'CLCT',
#  'CLDR',
#  'CLDT',
#  'CLF',
#  'CLFD',
#  'CLGX',
#  'CLH',
#  'CLNE',
#  'CLR',
#  'CLRB',
#  'CLX',
#  'CMBG',
#  'CMBM',
#  'CMC',
#  'CMCO',
#  'CMCSA',
#  'CMD',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMLS',
#  'CMND',
#  'CMP',
#  'CMPR',
#  'CMRO',
#  'CMS',
#  'CMT',
#  'CMTL',
#  'CNC',
#  'CNDT',
#  'CNK',
#  'CNM',
#  'CNNX',
#  'CNP',
#  'CNR',
#  'CNS',
#  'CNSL',
#  'CNVR',
#  'CNX',
#  'CNXC',
#  'CNXR',
#  'CNXT',
#  'CODA',
#  'CODI',
#  'COG',
#  'COGT',
#  'COHR',
#  'COIN',
#  'COKE',
#  'COL',
#  'COLM',
#  'COMM',
#  'CONE',
#  'CONN',
#  'COO',
#  'COP',
#  'COR',
#  'CORT',
#  'COST',
#  'COT',
#  'COTV',
#  'COTY',
#  'COUP',
#  'COVS',
#  'CP',
#  'CPB',
#  'CPLG',
#  'CPN',
#  'CPRI',
#  'CPRT',
#  'CPS',
#  'CPSI',
#  'CPT',
#  'CPXX',
#  'CQH',
#  'CQP',
#  'CR',
#  'CRAY',
#  'CRBU',
#  'CRC',
#  'CRD-A',
#  'CRDF',
#  'CREE',
#  'CRI',
#  'CRIS',
#  'CRL',
#  'CRM',
#  'CRNC',
#  'CROX',
#  'CRR',
#  'CRS',
#  'CRSP',
#  'CRSR',
#  'CRTO',
#  'CRUS',
#  'CRVS',
#  'CRWD',
#  'CRWS',
#  'CRY',
#  'CRZO',
#  'CSBR',
#  'CSC',
#  'CSCO',
#  'CSGP',
#  'CSGS',
#  'CSII',
#  'CSL',
#  'CSLT',
#  'CSOD',
#  'CSPR',
#  'CSRA',
#  'CSS',
#  'CST',
#  'CSTL',
#  'CSU',
#  'CSWI',
#  'CSX',
#  'CTAS',
#  'CTIC',
#  'CTLP',
#  'CTLT',
#  'CTMX',
#  'CTOP',
#  'CTS',
#  'CTSH',
#  'CTVA',
#  'CTXS',
#  'CUB',
#  'CUBE',
#  'CULP',
#  'CUO',
#  'CUTR',
#  'CUZ',
#  'CVA',
#  'CVCO',
#  'CVGI',
#  'CVLT',
#  'CVNA',
#  'CVS',
#  'CVSI',
#  'CVX',
#  'CW',
#  'CWEN',
#  'CWH',
#  'CWRL',
#  'CWT',
#  'CXO',
#  'CXP',
#  'CXW',
#  'CY',
#  'CYAN',
#  'CYCA',
#  'CYCC',
#  'CYIG',
#  'CYNX',
#  'CZR',
#  'D',
#  'DAL',
#  'DALN',
#  'DAN',
#  'DAR',
#  'DASH',
#  'DATA',
#  'DBD',
#  'DBI',
#  'DBX',
#  'DCI',
#  'DCPH',
#  'DD',
#  'DDD',
#  'DDE',
#  'DDMG',
#  'DDOG',
#  'DDS',
#  'DE',
#  'DEA',
#  'DECK',
#  'DEI',
#  'DELL',
#  'DEN',
#  'DENN',
#  'DESTQ',
#  'DEVV',
#  'DFCO',
#  'DFODQ',
#  'DFT',
#  'DG',
#  'DGTC',
#  'DGX',
#  'DHR',
#  'DHX',
#  'DIN',
#  'DIS',
#  'DISCA',
#  'DISH',
#  'DIT',
#  'DK',
#  'DKNG',
#  'DKS',
#  'DLB',
#  'DLPH',
#  'DLTH',
#  'DLTR',
#  'DLX',
#  'DMDW',
#  'DMRC',
#  'DMTK',
#  'DNAY',
#  'DNB',
#  'DNKN',
#  'DNOW',
#  'DOC',
#  'DOCN',
#  'DOCU',
#  'DOMO',
#  'DORM',
#  'DOV',
#  'DOW',
#  'DPLO',
#  'DPZ',
#  'DRE',
#  'DRI',
#  'DRQ',
#  'DRTT',
#  'DS',
#  'DSKE',
#  'DT',
#  'DTE',
#  'DTIL',
#  'DTM',
#  'DTRM',
#  'DUK',
#  'DUOL',
#  'DVA',
#  'DVAX',
#  'DVN',
#  'DXC',
#  'DXCM',
#  'DXLG',
#  'DXPE',
#  'DY',
#  'DYN',
#  'DYNT',
#  'DZSI',
#  'EA',
#  'EAF',
#  'EAST',
#  'EAT',
#  'EB',
#  'EBAY',
#  'EBF',
#  'EBIX',
#  'EBS',
#  'ECA',
#  'ECL',
#  'ECYT',
#  'ED',
#  'EDIT',
#  'EE',
#  'EEFT',
#  'EEI',
#  'EFOI',
#  'EFX',
#  'EGAN',
#  'EGHT',
#  'EGLT',
#  'EGP',
#  'EGY',
#  'EHC',
#  'EHTH',
#  'EIGI',
#  'EIX',
#  'EL',
#  'ELAN',
#  'ELLI',
#  'ELMD',
#  'ELS',
#  'ELY',
#  'ELYS',
#  'EMC',
#  'EME',
#  'EMN',
#  'EMR',
#  'ENB',
#  'ENBL',
#  'ENDP',
#  'ENG',
#  'ENPH',
#  'ENR',
#  'ENS',
#  'ENV',
#  'ENZ',
#  'EOG',
#  'EPAC',
#  'EPAM',
#  'EPAY',
#  'EPD',
#  'EPE',
#  'EPM',
#  'EPRT',
#  'EPZM',
#  'EQIX',
#  'EQM',
#  'EQR',
#  'EQT',
#  'ERS',
#  'ES',
#  'ESCA',
#  'ESI',
#  'ESL',
#  'ESP',
#  'ESRX',
#  'ESS',
#  'ESTA',
#  'ESTC',
#  'ETD',
#  'ETEC',
#  'ETM',
#  'ETN',
#  'ETR',
#  'ETRN',
#  'ETSY',
#  'EV',
#  'EVA',
#  'EVBG',
#  'EVC',
#  'EVCM',
#  'EVFM',
#  'EVH',
#  'EVI',
#  'EVLO',
#  'EVOP',
#  'EVR',
#  'EVRG',
#  'EVRI',
#  'EVTC',
#  'EW',
#  'EXA',
#  'EXAS',
#  'EXC',
#  'EXDX',
#  'EXEL',
#  'EXP',
#  'EXPD',
#  'EXPE',
#  'EXPI',
#  'EXPO',
#  'EXPR',
#  'EXR',
#  'EXTR',
#  'EYPT',
#  'F',
#  'FANG',
#  'FARM',
#  'FARO',
#  'FAST',
#  'FB',
#  'FBHS',
#  'FBRX',
#  'FC',
#  'FCEL',
#  'FCFS',
#  'FCN',
#  'FCPT',
#  'FCS',
#  'FCX',
#  'FDC',
#  'FDS',
#  'FDX',
#  'FE',
#  'FEIM',
#  'FELE',
#  'FET',
#  'FEYE',
#  'FF',
#  'FFIV',
#  'FGEN',
#  'FGP',
#  'FHI',
#  'FICO',
#  'FIS',
#  'FISV',
#  'FIT',
#  'FIVE',
#  'FIVN',
#  'FIX',
#  'FIZZ',
#  'FKWL',
#  'FL',
#  'FLDM',
#  'FLGT',
#  'FLIR',
#  'FLLC',
#  'FLO',
#  'FLOW',
#  'FLR',
#  'FLS',
#  'FLT',
#  'FLUG',
#  'FLWS',
#  'FLXS',
#  'FMC',
#  'FMSA',
#  'FND',
#  'FNJN',
#  'FNKO',
#  'FNSR',
#  'FOE',
#  'FOLD',
#  'FONR',
#  'FOR',
#  'FORD',
#  'FORM',
#  'FORR',
#  'FOSL',
#  'FOUR',
#  'FOX',
#  'FOXF',
#  'FPH',
#  'FPRX',
#  'FR',
#  'FRANQ',
#  'FRD',
#  'FRED',
#  'FRGI',
#  'FROG',
#  'FRP',
#  'FRPT',
#  'FRT',
#  'FRX',
#  'FSCT',
#  'FSLR',
#  'FSLY',
#  'FSS',
#  'FTDR',
#  'FTEK',
#  'FTI',
#  'FTK',
#  'FTNT',
#  'FTRCQ',
#  'FTV',
#  'FUEL',
#  'FUL',
#  'G',
#  'GAIA',
#  'GAMZ',
#  'GBT',
#  'GBX',
#  'GCI',
#  'GCO',
#  'GD',
#  'GDDY',
#  'GDI',
#  'GDOT',
#  'GDRX',
#  'GE',
#  'GEF',
#  'GEL',
#  'GENC',
#  'GEO',
#  'GEOS',
#  'GERN',
#  'GES',
#  'GEVO',
#  'GFF',
#  'GGG',
#  'GH',
#  'GHC',
#  'GHDX',
#  'GIDYL',
#  'GIII',
#  'GILD',
#  'GIMO',
#  'GIS',
#  'GLGI',
#  'GLP',
#  'GLPI',
#  'GLUU',
#  'GLW',
#  'GLYC',
#  'GM',
#  'GMAN',
#  'GME',
#  'GMED',
#  'GNRC',
#  'GNTX',
#  'GO',
#  'GOEV',
#  'GOOD',
#  'GOOG',
#  'GPC',
#  'GPN',
#  'GPORQ',
#  'GPRE',
#  'GPRO',
#  'GPS',
#  'GRA',
#  'GRC',
#  'GRMM',
#  'GRMN',
#  'GRPH',
#  'GRPN',
#  'GRUB',
#  'GRWG',
#  'GSHD',
#  'GSIT',
#  'GT',
#  'GTHX',
#  'GTT',
#  'GUID',
#  'GWGH',
#  'GWPH',
#  'GWR',
#  'GWRE',
#  'GWRS',
#  'GWW',
#  'GXP',
#  'H',
#  'HABT',
#  'HAE',
#  'HAIN',
#  'HAL',
#  'HALO',
#  'HAR',
#  'HAS',
#  'HAYN',
#  'HBI',
#  ...]

# %%
all_df = combiner(companies_clean)

# %%
#amzn_df.drop(columns=['Fiscal Year','Fiscal Period','SimFinId','Adj. Close','Dividends Per Share', 'Dividend Payout Ratio'],inplace=True)
all_df['pct_change'][all_df['pct_change'] < 0] = 0
all_df['pct_change'][all_df['pct_change'] > 0] = 1
all_df.head()
# Out:
#    Gross Profit Margin  Operating Margin  Net Profit Margin  Return on Equity  \
# 0              0.52384           0.08309            0.14812           0.07295
# 1              0.52919           0.12881            0.18528           0.09023
# 2              0.53720           0.13891            0.12706           0.05780
# 3              0.53667           0.15862            0.11926           0.05049
# 4              0.52750           0.16617            0.19515           0.07857
#
#    Return on Assets  Free Cash Flow to Net Income  Current Ratio  \
# 0           0.02253                       0.84878        1.96606
# 1           0.03012                       0.88356        2.00097
# 2           0.02399                       0.33679        3.27027
# 3           0.02312                       1.96500        3.20101
# 4           0.03770                       0.22424        3.47043
#
#    Liabilities to Equity Ratio  Debt Ratio  Earnings Per Share, Basic  \
# 0                      2.23843     0.40418                    0.59078
# 1                      1.99629     0.38067                    0.84884
# 2                      1.40910     0.26591                    0.55620
# 3                      1.18354     0.24789                    0.57637
# 4                      1.08405     0.24769                    0.94828
#
#    Earnings Per Share, Diluted  Sales Per Share  Equity Per Share  \
# 0                      0.58239          3.98847           8.07493
# 1                      0.82022          4.58140           9.38372
# 2                      0.54366          4.37752           9.60231
# 3                      0.56338          4.83285          11.39193
# 4                      0.92437          4.85920          12.04598
#
#    Free Cash Flow Per Share  Return On Invested Capital  \
# 0                   0.50144                     0.02668
# 1                   0.75000                     0.03599
# 2                   0.18732                     0.02907
# 3                   1.13256                     0.02834
# 4                   0.21264                     0.04553
#
#    Cash Return On Invested Capital  Net Debt / EBITDA  Net Debt / EBIT  \
# 0                          0.02264            7.77714         11.83478
# 1                          0.03180            3.85926          5.13300
# 2                          0.00979           -1.82117         -2.36493
# 3                          0.05569           -2.51818         -3.12406
# 4                          0.01021           -2.71221         -3.32028
#
#    SimFinId  pct_change
# 0   45846.0         1.0
# 1   45846.0         1.0
# 2   45846.0         0.0
# 3   45846.0         1.0
# 4   45846.0         0.0

# %%
all_df.reset_index(drop=True, inplace=True)
#all_df.drop(columns=['Fiscal Year', 'Fiscal Period', 'Adj. Close', 'Dividends Per Share', 'Piotroski F-Score'],inplace=True)
all_df.drop(columns=['Dividend Payout Ratio'],inplace=True)
all_df.head()
# Out:
#    Gross Profit Margin  Operating Margin  Net Profit Margin  Return on Equity  \
# 0              0.52384           0.08309            0.14812           0.07295
# 1              0.52919           0.12881            0.18528           0.09023
# 2              0.53720           0.13891            0.12706           0.05780
# 3              0.53667           0.15862            0.11926           0.05049
# 4              0.52750           0.16617            0.19515           0.07857
#
#    Return on Assets  Free Cash Flow to Net Income  Current Ratio  \
# 0           0.02253                       0.84878        1.96606
# 1           0.03012                       0.88356        2.00097
# 2           0.02399                       0.33679        3.27027
# 3           0.02312                       1.96500        3.20101
# 4           0.03770                       0.22424        3.47043
#
#    Liabilities to Equity Ratio  Debt Ratio  Earnings Per Share, Basic  \
# 0                      2.23843     0.40418                    0.59078
# 1                      1.99629     0.38067                    0.84884
# 2                      1.40910     0.26591                    0.55620
# 3                      1.18354     0.24789                    0.57637
# 4                      1.08405     0.24769                    0.94828
#
#    Earnings Per Share, Diluted  Sales Per Share  Equity Per Share  \
# 0                      0.58239          3.98847           8.07493
# 1                      0.82022          4.58140           9.38372
# 2                      0.54366          4.37752           9.60231
# 3                      0.56338          4.83285          11.39193
# 4                      0.92437          4.85920          12.04598
#
#    Free Cash Flow Per Share  Return On Invested Capital  \
# 0                   0.50144                     0.02668
# 1                   0.75000                     0.03599
# 2                   0.18732                     0.02907
# 3                   1.13256                     0.02834
# 4                   0.21264                     0.04553
#
#    Cash Return On Invested Capital  Net Debt / EBITDA  Net Debt / EBIT  \
# 0                          0.02264            7.77714         11.83478
# 1                          0.03180            3.85926          5.13300
# 2                          0.00979           -1.82117         -2.36493
# 3                          0.05569           -2.51818         -3.12406
# 4                          0.01021           -2.71221         -3.32028
#
#    SimFinId  pct_change
# 0     45846    0.016256
# 1     45846    0.004856
# 2     45846   -0.025379
# 3     45846    0.000955
# 4     45846   -0.043367

# %%
np.any(np.isnan(all_df))
np.all(np.isfinite(all_df))

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
all_df = clean_dataset(all_df)
all_df.head()
# Out:
#    Gross Profit Margin  Operating Margin  Net Profit Margin  Return on Equity  \
# 0              0.52384           0.08309            0.14812           0.07295
# 1              0.52919           0.12881            0.18528           0.09023
# 2              0.53720           0.13891            0.12706           0.05780
# 3              0.53667           0.15862            0.11926           0.05049
# 4              0.52750           0.16617            0.19515           0.07857
#
#    Return on Assets  Free Cash Flow to Net Income  Current Ratio  \
# 0           0.02253                       0.84878        1.96606
# 1           0.03012                       0.88356        2.00097
# 2           0.02399                       0.33679        3.27027
# 3           0.02312                       1.96500        3.20101
# 4           0.03770                       0.22424        3.47043
#
#    Liabilities to Equity Ratio  Debt Ratio  Earnings Per Share, Basic  \
# 0                      2.23843     0.40418                    0.59078
# 1                      1.99629     0.38067                    0.84884
# 2                      1.40910     0.26591                    0.55620
# 3                      1.18354     0.24789                    0.57637
# 4                      1.08405     0.24769                    0.94828
#
#    Earnings Per Share, Diluted  Sales Per Share  Equity Per Share  \
# 0                      0.58239          3.98847           8.07493
# 1                      0.82022          4.58140           9.38372
# 2                      0.54366          4.37752           9.60231
# 3                      0.56338          4.83285          11.39193
# 4                      0.92437          4.85920          12.04598
#
#    Free Cash Flow Per Share  Return On Invested Capital  \
# 0                   0.50144                     0.02668
# 1                   0.75000                     0.03599
# 2                   0.18732                     0.02907
# 3                   1.13256                     0.02834
# 4                   0.21264                     0.04553
#
#    Cash Return On Invested Capital  Net Debt / EBITDA  Net Debt / EBIT  \
# 0                          0.02264            7.77714         11.83478
# 1                          0.03180            3.85926          5.13300
# 2                          0.00979           -1.82117         -2.36493
# 3                          0.05569           -2.51818         -3.12406
# 4                          0.01021           -2.71221         -3.32028
#
#    SimFinId  pct_change
# 0   45846.0    0.016256
# 1   45846.0    0.004856
# 2   45846.0   -0.025379
# 3   45846.0    0.000955
# 4   45846.0   -0.043367

# %%
# Prepare Train and Test 
X = all_df.copy()
X.drop("pct_change", axis=1, inplace=True)
X.head()


y = all_df['pct_change']
y.head()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions = rf_model.predict(X_test_scaled)

# %%
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         4456         3700
# Actual 1         3987         4088
# Accuracy Score : 0.5264000985767975
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.55      0.54      8156
#          1.0       0.52      0.51      0.52      8075
#
#     accuracy                           0.53     16231
#    macro avg       0.53      0.53      0.53     16231
# weighted avg       0.53      0.53      0.53     16231
